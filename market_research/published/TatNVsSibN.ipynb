# %%
from stdimports import *
# %matplotlib inline

instr=[('TATN',fe.Market.SHARES),('SIBN',fe.Market.SHARES)]
df=utils.getMd(instr, fe.Timeframe.DAILY)
# Out:
#  last updated time is 2019-08-25 17:28:29.993698
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=825&market=1&df=1&mf=0&yf=2017&dt=25&mt=7&yt=2019&cn=TATN&code=TATN&datf=5
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=2&market=1&df=1&mf=0&yf=2017&dt=25&mt=7&yt=2019&cn=SIBN&code=SIBN&datf=5

# %% [markdown]
# ## Tatn vs Sibn
# ### last 1200 days

# %%
plt.rcParams["figure.dpi"] = 500
df.tail(1200).pct_change().fillna(0).add(1).cumprod().plot(title='last ');

# %% [markdown]
# ### last 600 days

# %%
plt.rcParams["figure.dpi"] = 500
df.tail(600).pct_change().fillna(0).add(1).cumprod().plot();
