# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from stdimports import *
# %matplotlib inline
instr=[('SBER',fe.Market.SHARES),('SBERP',fe.Market.SHARES)]
df_chmf=utils.getMd(instr, fe.Timeframe.DAILY)
# Out:
#  last updated time is 2020-03-15 15:02:19.870393
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=3&market=1&df=1&mf=0&yf=2017&dt=15&mt=2&yt=2020&cn=SBER&code=SBER&datf=5
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=23&market=1&df=1&mf=0&yf=2017&dt=15&mt=2&yt=2020&cn=SBERP&code=SBERP&datf=5

# %% [markdown]
# ## Sber vs Sber pref
# ### last 600 days

# %%
plt.rcParams["figure.dpi"] = 500
dff=df_chmf.tail(1200)
(dff.SBER_close/dff.SBERP_close ).plot()

# %% [markdown]
# ### last 300 days

# %%
plt.rcParams["figure.dpi"] = 500
df_chmf.tail(300).pct_change().fillna(0).add(1).cumprod().plot();
