# %%
from market_research.published.stdimports import *
# %matplotlib inline
instr=[('SBER',fe.Market.SHARES),('SBERP',fe.Market.SHARES)]
df_chmf=utils.getMd(instr, fe.Timeframe.DAILY)
# Out:
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=3&market=1&df=1&mf=0&yf=2017&dt=25&mt=7&yt=2019&cn=SBER&code=SBER&datf=5
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=23&market=1&df=1&mf=0&yf=2017&dt=25&mt=7&yt=2019&cn=SBERP&code=SBERP&datf=5

# %% [markdown]
# ## Sber vs Sber pref
# ### last 600 days

# %%
plt.rcParams["figure.dpi"] = 500
df_chmf.tail(600).pct_change().fillna(0).add(1).cumprod().plot();

# %% [markdown]
# ### last 300 days

# %%
plt.rcParams["figure.dpi"] = 500
df_chmf.tail(300).pct_change().fillna(0).add(1).cumprod().plot();
