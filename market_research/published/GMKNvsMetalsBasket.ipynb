# %%
from stdimports import *
# %matplotlib inline
instr=[('NI',fe.Market.COMMODITIES),('GMKN',fe.Market.SHARES),('NYMEX.PA',fe.Market.COMMODITIES),
       ('NYMEX.PL',fe.Market.COMMODITIES),('CA',fe.Market.COMMODITIES),('USDCB',fe.Market.M41)]
df=utils.getMd(instr, fe.Timeframe.DAILY)
df['basket']=df.USDCB_close*(df.NI_close*0.25+df.CA_close*0.25+df['NYMEX.PA_close']*0.25)
df=df[['GMKN_close','basket']]
# Out:
#  last updated time is 2019-08-25 17:22:58.122691
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=18932&market=24&df=1&mf=0&yf=2017&dt=25&mt=7&yt=2019&cn=NI&code=NI&datf=5
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=795&market=1&df=1&mf=0&yf=2017&dt=25&mt=7&yt=2019&cn=GMKN&code=GMKN&datf=5
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=18959&market=24&df=1&mf=0&yf=2017&dt=25&mt=7&yt=2019&cn=NYMEX.PA&code=NYMEX.PA&datf=5
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=18947&market=24&df=1&mf=0&yf=2017&dt=25&mt=7&yt=2019&cn=NYMEX.PL&code=NYMEX.PL&datf=5
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=18931&market=24&df=1&mf=0&yf=2017&dt=25&mt=7&yt=2019&cn=CA&code=CA&datf=5
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=82485&market=41&df=1&mf=0&yf=2017&dt=25&mt=7&yt=2019&cn=USDCB&code=USDCB&datf=5

# %% [markdown]
# ## GMK NorNikel againts basket of equiwegihted (palladium nikkel copper) in rubles
# ### last 600 days

# %%
plt.rcParams["figure.dpi"] = 500
df.tail(600).pct_change().fillna(0).add(1).cumprod().plot();
