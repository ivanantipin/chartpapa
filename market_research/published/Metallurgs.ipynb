# %%
from stdimports import *
# %matplotlib inline

instr=[('CHMF',fe.Market.SHARES),('NLMK',fe.Market.SHARES),('MAGN',fe.Market.SHARES)]
df=utils.getMd(instr, fe.Timeframe.DAILY)
# Out:
#  last updated time is 2019-08-25 17:43:06.744576
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=16136&market=1&df=1&mf=0&yf=2017&dt=25&mt=7&yt=2019&cn=CHMF&code=CHMF&datf=5
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=17046&market=1&df=1&mf=0&yf=2017&dt=25&mt=7&yt=2019&cn=NLMK&code=NLMK&datf=5
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=16782&market=1&df=1&mf=0&yf=2017&dt=25&mt=7&yt=2019&cn=MAGN&code=MAGN&datf=5

# %% [markdown]
# ## Russian metal companies NLMK/CHMF/MAGN
# ### last 2000 days

# %%
plt.rcParams["figure.dpi"] = 500
df.tail(2000).pct_change().fillna(0).add(1).cumprod().plot();

# %% [markdown]
# ### last 1200 days

# %%
plt.rcParams["figure.dpi"] = 500
df.tail(1200).pct_change().fillna(0).add(1).cumprod().plot();

# %% [markdown]
# ### last 300 days

# %%
plt.rcParams["figure.dpi"] = 500
df.tail(300).pct_change().fillna(0).add(1).cumprod().plot();
