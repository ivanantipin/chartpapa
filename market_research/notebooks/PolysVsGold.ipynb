# %%
import importlib

import utils


# %matplotlib notebook

# %matplotlib inline

import finam.export as fe

importlib.reload(fe) 
importlib.reload(utils)

instr=[('GC',fe.Market.COMMODITIES),('PLZL',fe.Market.SHARES),('POLY',fe.Market.SHARES),('USDCB',fe.Market.M41)]


# df_steel_index=utils.getFredMd('WPU101707')
df_chmf=utils.getMd(instr, fe.Timeframe.DAILY)

df_chmf['sint']=df_chmf.USDCB_close*df_chmf.GC_close

gld_df = df_chmf.GC_close

df_chmf=df_chmf[['POLY_close','PLZL_close','sint']]
# Out:
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=18953&market=24&df=1&mf=0&yf=2017&dt=2&mt=1&yt=2020&cn=GC&code=GC&datf=5
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=17123&market=1&df=1&mf=0&yf=2017&dt=2&mt=1&yt=2020&cn=PLZL&code=PLZL&datf=5
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=175924&market=1&df=1&mf=0&yf=2017&dt=2&mt=1&yt=2020&cn=POLY&code=POLY&datf=5
# http://export.finam.ru/table.csv?d=d&f=table&e=.csv&dtf=1&tmf=3&MSOR=0&mstime=on&mstimever=1&sep=3&sep2=1&at=1&p=8&em=82485&market=41&df=1&mf=0&yf=2017&dt=2&mt=1&yt=2020&cn=USDCB&code=USDCB&datf=5

# %%
df_chmf.tail(200).pct_change().fillna(0).add(1).cumprod().plot()

# %%
gld_df
# Out:
# index
# 2017-01-10    1189.0
# 2017-01-11    1198.6
# 2017-01-12    1193.5
# 2017-01-13    1197.3
# 2017-01-17    1211.8
#                ...
# 2020-01-24    1571.3
# 2020-01-28    1567.5
# 2020-01-29    1576.7
# 2020-01-30    1579.7
# 2020-01-31    1593.6
# Name: GC_close, Length: 590, dtype: float64
